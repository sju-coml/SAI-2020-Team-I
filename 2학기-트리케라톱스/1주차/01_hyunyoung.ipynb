# %% [markdown]
# ### 데이터 셋

# %%
# 케라스에서 MNIST 데이터 셋 적재
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Using TensorFlow backend.
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 8a61469f7ea1b51cbae51d4f78837e45 so we will re-download the data.
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 47s 4us/step

# %%
# train set
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
# test set
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %% [markdown]
# ### 신경망 구조

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

# Fully Connected 된 Dense층 2개
network =  models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(28*28,)))
network.add(layers.Dense(10, activation='softmax'))

# %% [markdown]
# ### 컴파일 단계
# * 손실 함수
# * 옵티마이저
# * 훈련, 테스트 과정 모니터링 지표

# %%
network.compile(optimizer='rmsprop', 
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %% [markdown]
# ### 스케일 조정
# * mnist이미지는 [0,255] 사이의 값인 unit8타입의 (60000, 28, 28) 크기의 배열임
# * 이를 [0,1] 사이의 값인 float32타입의 (60000, 28  * 28) 크기 배열로 변경

# %%
train_images = train_images.reshape(60000, 28*28)
train_images = train_images.astype('float32')/255

test_images = test_images.reshape(10000, 28*28)
test_images = test_images.astype('float32')/255

# %% [markdown]
# ### 레이블을 범주형으로 인코딩

# %%
from keras.utils import to_categorical

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# ### 신경망 훈련

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Train on 60000 samples
# Epoch 1/5
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000017D57487B88> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000017D57487B88>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000017D57487B88> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000017D57487B88>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 60000/60000 [==============================] - 8s 129us/sample - loss: 0.2555 - accuracy: 0.9252
# Epoch 2/5
# 60000/60000 [==============================] - 7s 114us/sample - loss: 0.1017 - accuracy: 0.9696
# Epoch 3/5
# 60000/60000 [==============================] - 8s 133us/sample - loss: 0.0676 - accuracy: 0.9792
# Epoch 4/5
# 60000/60000 [==============================] - 7s 121us/sample - loss: 0.0496 - accuracy: 0.9850
# Epoch 5/5
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.0374 - accuracy: 0.9888

# %% [markdown]
# ### 예측 수행

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('test_acc:', test_acc)
# Out:
# test_acc: 0.9803
